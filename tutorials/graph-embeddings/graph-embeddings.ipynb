# %%
import numpy as np
import random
import networkx as nx
from IPython.display import Image
import matplotlib.pyplot as plt

from node2vec import Node2Vec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Daniel\Documents\Python Projects\AiPEX-Projects\tutorials\graph-embeddings\graph-embeddings.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Daniel/Documents/Python%20Projects/AiPEX-Projects/tutorials/graph-embeddings/graph-embeddings.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from IPython.display import Image
#       <a href='vscode-notebook-cell:/c%3A/Users/Daniel/Documents/Python%20Projects/AiPEX-Projects/tutorials/graph-embeddings/graph-embeddings.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Daniel/Documents/Python%20Projects/AiPEX-Projects/tutorials/graph-embeddings/graph-embeddings.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> from node2vec import Node2Vec
#
# ModuleNotFoundError: No module named 'node2vec'

# %%
n=34
m = 78
G_karate = nx.karate_club_graph()

pos = nx.spring_layout(G_karate)
nx.draw(G_karate, cmap = plt.get_cmap('rainbow'), with_labels=True, pos=pos)
# Out:
# c:\Users\Daniel\miniconda3\envs\bond-graph\lib\site-packages\networkx\drawing\nx_pylab.py:433: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
